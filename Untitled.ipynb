# %%
from sklearn.datasets import fetch_openml
import numpy as np
# dataset = fetch_openml("cmc", version=1)
# np.save("dataset.npy", dataset)
dataset = np.load("dataset.npy", allow_pickle=True)

# %%
description = dataset.flat[0]['DESCR']
print(description)
# Out:
# **Author**: [Tjen-Sien Lim](limt@stat.wisc.edu)
# **Source**: [As obtained from UCI](https://archive.ics.uci.edu/ml/datasets/Contraceptive+Method+Choice)
# **Please cite**: [UCI citation](https://archive.ics.uci.edu/ml/citation_policy.html)
#
# 1. Title: Contraceptive Method Choice
#
#  2. Sources:
#     (a) Origin:  This dataset is a subset of the 1987 National Indonesia
#                  Contraceptive Prevalence Survey
#     (b) Creator: Tjen-Sien Lim (limt@stat.wisc.edu)
#     (c) Donor:   Tjen-Sien Lim (limt@stat.wisc.edu)
#     (c) Date:    June 7, 1997
#
#  3. Past Usage:
#     Lim, T.-S., Loh, W.-Y. & Shih, Y.-S. (1999). A Comparison of
#     Prediction Accuracy, Complexity, and Training Time of Thirty-three
#     Old and New Classification Algorithms. Machine Learning. Forthcoming.
#     (ftp://ftp.stat.wisc.edu/pub/loh/treeprogs/quest1.7/mach1317.pdf or
#     (http://www.stat.wisc.edu/~limt/mach1317.pdf)
#
#  4. Relevant Information:
# ...

# %%
data = dataset.flat[0]['frame']
values = data.loc[:, 'Wifes_age':'Media_exposure']
labels = pd.DataFrame(data.loc[:, 'Contraceptive_method_used'])
X, y = [df.to_numpy() for df in (values, labels)]
X = X.astype('int')

# %% [markdown]
# I chose to scale the features using MinMaxScaler, as it provided a way to scale while also keeping the relevant information about importance.
# For example, there is still differentiation between educated and uneducated parents, standard of living and so on.
# ! Actually, in hindsight, scaling yielded worse accuracy with the SGDClassifier class.

# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
mms = MinMaxScaler()
X_scaled = mms.fit_transform(X)

# %%
# X_columns, y_columns = X.columns, y.columns
# X, y = [pd.DataFrame(array) for array in (X_scaled, y_scaled)]
# X.columns, y.columns = X_columns, y_columns

# %% [markdown]
# We will proceed with separating the training and the test sets:

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
y_train, y_test = [array.ravel() for array in (y_train, y_test)]

# %% [markdown]
# Now, for the classification:

# %%
from sklearn.linear_model import SGDClassifier
sgd_clf = SGDClassifier(n_jobs=-1, random_state=42)
sgd_clf.fit(X_train, y_train)
# Out:
# SGDClassifier(n_jobs=-1, random_state=42)

# %%
from sklearn.model_selection import cross_val_score
cvs = cross_val_score(
    sgd_clf,
    X_test,
    y = y_test,
    cv = 3,
    n_jobs = -1
)
cvs
# Out:
# array([0.47154472, 0.56097561, 0.47154472])
